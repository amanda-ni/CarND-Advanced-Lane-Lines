# %%
import pickle
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# Read in the saved camera matrix and distortion coefficients
# These are the arrays you calculated using cv2.calibrateCamera()
dist_pickle = pickle.load( open( "wide_dist_pickle.p", "rb" ) )
mtx = dist_pickle["mtx"]
dist = dist_pickle["dist"]

# Read in an image
img = cv2.imread('../../camera_cal/calibration3.jpg')

nx = 8 # the number of inside corners in x
ny = 6 # the number of inside corners in y
nx = 7 # the number of inside corners in x
ny = 4 # the number of inside corners in y


# MODIFY THIS FUNCTION TO GENERATE OUTPUT 
# THAT LOOKS LIKE THE IMAGE ABOVE
def corners_unwarp(img, nx, ny, mtx, dist):
    # Pass in your image into this function
    # Write code to do the following steps
    # 1) Undistort using mtx and dist
    undistorted = cv2.undistort(img, mtx, dist)
    
    # 2) Convert to grayscale
    warped = cv2.cvtColor(undistorted, cv2.COLOR_BGR2GRAY)
    
    # 3) Find the chessboard corners
    ret, corners = cv2.findChessboardCorners(warped, (nx, ny), None)

    # 4) If corners found: 
    if ret:
        print("{} corners found!".format(len(corners)))
            # a) draw corners
        warped = cv2.drawChessboardCorners(warped, (8,6), corners, ret)

            # b) define 4 source points src = np.float32([[,],[,],[,],[,]])
                 #Note: you could pick any four of the detected corners 
                 # as long as those four corners define a rectangle
                 #One especially smart way to do this would be to use four well-chosen
                 # corners that were automatically detected during the undistortion steps
                 #We recommend using the automatic detection of corners in your code
        src = np.float32(np.concatenate( (corners[0],  corners[nx-1] , 
                                          corners[-1], corners[-nx] ) ) )

            # c) define 4 destination points dst = np.float32([[,],[,],[,],[,]])
        imshape = (img.shape[1], img.shape[0])
        dst = np.float32(np.array( [[100,100], [imshape[0]-100,100], 
                                   [imshape[0]-100,imshape[1]-100], 
                                   [100, imshape[1]-100]] ) )

            # d) use cv2.getPerspectiveTransform() to get M, the transform matrix
        M = cv2.getPerspectiveTransform(src, dst)
        
            # e) use cv2.warpPerspective() to warp your image to a top-down view
        warped = cv2.warpPerspective(undistorted, M, imshape[:2])
    else:
        print("ERROR: Could not find any corners")
        warped = undistorted
        M = None
        
    return warped, M

top_down, perspective_M = corners_unwarp(img, nx, ny, mtx, dist)
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(24, 9))
f.tight_layout()
ax1.imshow(img)
ax1.set_title('Original Image', fontsize=50)
ax2.imshow(top_down)
ax2.set_title('Undistorted and Warped Image', fontsize=50)
plt.subplots_adjust(left=0., right=1, top=0.9, bottom=0.)
# Out:
# ERROR: Could not find any corners
